# %% [markdown]
# <a href="https://colab.research.google.com/github/vindyareddy2000/Edukron-DE/blob/Dev/String_Class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string="data"
string.upper()  ### SDF , system defined functions, udf : user defined functions
# Out:
# 'DATA'

# %%
string[0:2].upper()
# Out:
# 'DA'

# %%
a="Data"
a.lower()
# Out:
# 'data'

# %%
a="Data scienCe"
a.title()
# Out:
# 'Data Science'

# %%
a="data science"
a.capitalize()
# Out:
# 'Data science'

# %%
a="DATA"
a.isupper()
# Out:
# True

# %%
a="data6768 " ### space is excluded,numbers also ignoreed
a.islower()
# Out:
# True

# %%
### upper, lower().title,capitalize,isupper, is lower()

# %%
x="data22525"
x.isalpha() ### checks for only alphabets
# Out:
# False

# %%
x="1213141"
x.isalnum() ### checks for only alphabets
# Out:
# True

# %%
x="1213141"
x.isnumeric() ### checks for only alphabets
# Out:
# False

# %%
x="91-7338339898"
x.startswith("91")
# Out:
# True

# %%
x="91-73383 39898"
x.endswith("39898")
# Out:
# True

# %%
isalpha
isalnum
isnumerica
startswith
endswith

# %%
x=" science "
print(len(x))
x.strip()
print(len(x.strip()))
# Out:
# 9
# 7

# %%
x=" science "
print(len(x))
x.strip()
print(x.lstrip())
print(len(x.lstrip()))
# Out:
# 9
# science
# 8

# %%
x=" science "
print(len(x))
x.strip()
print(x.rstrip())
print(len(x.rstrip()))
# Out:
# 9
#  science
# 8

# %%
x="data"
x.zfill(6)

### if the original string is less than the output it will return full string
### if the original string is more
### than the output padding of zeros
### to match with the length
# Out:
# '00data'

# %%
x="data"
x.ljust(10,"0")
# Out:
# 'data000000'

# %%
x="data"
x.rjust(10,"0")
# Out:
# '000000data'

# %%
strip,lstrip,rstrip,rjust,ljust,zfill

# %%
x="data science data engineering"
x.split()
### default split happens based on space
# Out:
# ['data', 'science', 'data', 'engineering']

# %%
x="91-73383-9898"
x.split("-")
### default split happens based on space
# Out:
# ['91', '73383', '9898']

# %%
x="datat"
x.split("a")
# Out:
# ['d', 't', 't']

# %%
x="ata"
x.split("a")
# Out:
# ['', 't', '']

# %%
x="data sciencaaaae"
x.count("a")
# Out:
# 6

# %%
x="data science"
x.count("a",2,5) ### starting point, ending point
# Out:
# 1

# %%
x="data scienceaaaa"
### 0,1,2
x.count("a",2) ### starting point, ending point
# Out:
# 5

# %%
x="da sciencex,i tata"
x.index("DA")  ### position of the "a" m first occurance
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1878/1965395458.py in <cell line: 0>()
#       1 x="da sciencex,i tata"
# ----> 2 x.index("DA")  ### position of the "a" m first occurance
#
# ValueError: substring not found

# %%
### split,index,count,replace

# %%
x="datad data"
x.replace("d","xyz")
# Out:
# 'xyzataxyz xyzata'

# %%
x="data@"
x.replace("@","")
# Out:
# 'data'

# %%
x="data SCIENCe"
x.swapcase()
# Out:
# 'DATA sciencE'

# %%
x="data"
x.center(9,"*")
# Out:
# '***data**'

# %%
x="data"
y="10"
x+"5"
# Out:
# 'data5'

# %%
x*5
# Out:
# 'datadatadatadatadata'

# %%
x="data"
#output:DAta

# %%
x.replace("da","DA")
# Out:
# 'DAta'

# %%
x[0:2].upper()+x[2:]
# Out:
# 'DAta'

# %%
x="data science"
y="machine leanring"
output="****data****learning****"

# %%
#### notepad
