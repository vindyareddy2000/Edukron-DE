# %% [markdown]
# <a href="https://colab.research.google.com/github/vindyareddy2000/Edukron-DE/blob/Dev/Python_class_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 1. Write the indexing expression to print **"Edukron"**.
text = "Edukron Data Science and Data Engineering Batch 2026"

print(text[0:7])
print(text[:-45])
# Out:
# Edukron
# Edukron

# %%
### 2. Write the indexing expression to print **"Data"** (first occurrence).
print(text[8:12])
print(text[-44:-40])
# Out:
# Data
# Data

# %%
### Write the indexing expression to print **"Science"**.
print(text[13:20])
print(text[-39:-32])
# Out:
# Science
# Science

# %%
### 4. Write the indexing expression to print **"and"**.
print(text[21:24])
print(text[-31:-28])
# Out:
# and
# and

# %%
### 5. Write the indexing expression to print **"Data Engineering"**.
print(text[25:41])
print(text[-27:-11])
# Out:
# Data Engineering
# Data Engineering

# %%
### 6. Write the indexing expression to print "Engineering".
print(text[30:41])
print(text[-22:-11])
# Out:
# Engineering
# Engineering

# %%
### 7. Write the indexing expression to print "Batch".
print(text[42:47])
print(text[-10:-5])
# Out:
# Batch
# Batch

# %%
### 8. Write the indexing expression to print "2026".
print(text[48:])
print(text[-4:])
# Out:
# 2026
# 2026

# %%
### 9. Write the indexing expression to print "Science and Data".
print(text[13:29])
print(text[-39:-23])
# Out:
#  Science and Data
# Science and Data

# %%
### 10. Write the indexing expression to print "Data Science and Data Engineering Batch".
print(text[8:47])
print(text[-44:-5])
# Out:
# Data Science and Data Engineering Batch
# Data Science and Data Engineering Batch
